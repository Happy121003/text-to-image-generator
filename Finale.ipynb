# %%
# !pip install diffusers transformers accelerate safetensors

from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
from IPython.display import display

# Load the pipeline with Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float32,
).to("cpu")

# STEP 3: Ask user for input
prompt = input("Enter a description for the image you want to generate: ")

# STEP 4: Generate and show image
image = pipe(prompt).images[0]
display(image)

# STEP 5: Save image
image.save("generated_image.png")
print("Image saved as 'generated_image.png'")
# Out:
# Requirement already satisfied: diffusers in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (0.34.0)
# Requirement already satisfied: transformers in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (4.53.2)
# Requirement already satisfied: accelerate in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (1.9.0)
# Requirement already satisfied: safetensors in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (0.5.3)
# Requirement already satisfied: importlib_metadata in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.33.4)
# Requirement already satisfied: numpy in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.3.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.32.4)
# Requirement already satisfied: Pillow in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (11.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (2025.7.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (4.14.1)
# Requirement already satisfied: psutil in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from accelerate) (2.7.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\upend\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (2025.7.14)
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Enter a description for the image you want to generate:  a scenic mountain landscape with sunrise
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Image saved as 'generated_image.png'
